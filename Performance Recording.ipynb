# %%
from src.environment.TMNFEnv import TrackmaniaEnv
from stable_baselines3 import PPO
import keyboard
import pandas as pd
import numpy as np
import time

# %% [markdown]
# # Main Loop for capturing agent information

# %%
class random_agent:
    def __init__(self):
        self.id = 0

    def predict(self, obs):
        steering = 2*(np.random.random()-0.5)
        throttle = np.random.random()
        brake = 0
        action = [steering, throttle, brake]
        return action, None

# %%
testing_track = "C01"

""" Model type is random, or RL """
model_type = "RL"

env = TrackmaniaEnv(dimension_reduction=6,
                    training_track=testing_track,
                    training_mode="time_optimization", 
                    is_testing=True,
                    render_mode=None,
                    action_mode=None)

if model_type == "RL":
    model_type = "PPO"
    models_dir = "models/" + model_type
    model_watch_name = "PPO_C01_TO_speed=1.2"
    model_step = "1485k"
    
    model_path = f"{models_dir}/{model_watch_name}/{model_step}"
    model_to_watch = PPO.load(model_path, env=env)
else:
    model_watch_name = "random"
    model_step = "0k"
    model_to_watch = random_agent()

obs, _ = env.reset()

episode_count = 0
N_episodes = 55

checkpoint_time = []
total_distance = []
percentage_progress = []

while episode_count < N_episodes:
    
    action, _ = model_to_watch.predict(obs)
    obs, reward, done, _, info = env.step(action)

    # if info["checkpoint_time"] is not False:
    #     print("Finish time:", info["checkpoint_time"])

    if done:
        print(info)
        episode_count += 1

        checkpoint_time.append(info["checkpoint_time"])
        total_distance.append(info["total_distance"])
        percentage_progress.append(info["percentage_progress"])

    try:
        if keyboard.is_pressed("q"):
            print("Interrupt")
            break
    except:
        pass

env.close()
# Out:
# Registered to TMInterface0
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# {'checkpoint_time': False, 'total_distance': False, 'percentage_progress': False}
# {'checkpoint_time': False, 'total_distance': 0.0, 'percentage_progress': 0.0}
# {'checkpoint_time': False, 'total_distance': 1158.4194031292259, 'percentage_progress': 0.5878494010268112}
# {'checkpoint_time': 45.33, 'total_distance': 1996.241537542373, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': False, 'total_distance': 1152.2071753025562, 'percentage_progress': 0.587564175698802}
# {'checkpoint_time': False, 'total_distance': 1840.1337376192962, 'percentage_progress': 0.9324015972618368}
# {'checkpoint_time': False, 'total_distance': False, 'percentage_progress': False}
# {'checkpoint_time': False, 'total_distance': False, 'percentage_progress': False}
# {'checkpoint_time': False, 'total_distance': 4668.906056354509, 'percentage_progress': 0.403593839132915}
# {'checkpoint_time': False, 'total_distance': 798.0836616162082, 'percentage_progress': 0.4055904164289789}
# {'checkpoint_time': 42.02, 'total_distance': 1993.593533987392, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': 40.95, 'total_distance': 1991.5315945644033, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': False, 'total_distance': 781.0238759314128, 'percentage_progress': 0.3907586993725043}
# {'checkpoint_time': False, 'total_distance': False, 'percentage_progress': False}
# {'checkpoint_time': False, 'total_distance': 2696.187397748445, 'percentage_progress': 0.3904734740444952}
# {'checkpoint_time': False, 'total_distance': False, 'percentage_progress': False}
# {'checkpoint_time': 45.56, 'total_distance': 3905.243789757889, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': False, 'total_distance': 1179.0946056757393, 'percentage_progress': 0.600969766115231}
# {'checkpoint_time': 43.03, 'total_distance': 1990.5936224671482, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': 42.22, 'total_distance': 1996.4424029585198, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': False, 'total_distance': 841.8877479199666, 'percentage_progress': 0.4150028522532801}
# {'checkpoint_time': 42.9, 'total_distance': 1973.7373420157548, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': False, 'total_distance': 791.1294457690648, 'percentage_progress': 0.39760410724472334}
# {'checkpoint_time': 40.76, 'total_distance': 2006.5815407450182, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': False, 'total_distance': False, 'percentage_progress': False}
# {'checkpoint_time': False, 'total_distance': False, 'percentage_progress': False}
# {'checkpoint_time': False, 'total_distance': 4989.944647374006, 'percentage_progress': 0.5904164289788933}
# {'checkpoint_time': 41.07, 'total_distance': 1995.3258840983035, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': False, 'total_distance': False, 'percentage_progress': False}
# {'checkpoint_time': 45.32, 'total_distance': 3886.7022462568807, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': False, 'total_distance': 1193.2167840688342, 'percentage_progress': 0.6026811180832858}
# {'checkpoint_time': 41.55, 'total_distance': 1978.3579360938309, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': False, 'total_distance': False, 'percentage_progress': False}
# {'checkpoint_time': 44.69, 'total_distance': 3897.694222831195, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': 49.75, 'total_distance': 1981.806974888004, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': False, 'total_distance': 1192.2997825919344, 'percentage_progress': 0.6012549914432401}
# {'checkpoint_time': False, 'total_distance': False, 'percentage_progress': False}
# {'checkpoint_time': False, 'total_distance': False, 'percentage_progress': False}
# {'checkpoint_time': False, 'total_distance': False, 'percentage_progress': False}
# {'checkpoint_time': False, 'total_distance': False, 'percentage_progress': False}
# {'checkpoint_time': 40.96, 'total_distance': 8509.522578566872, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': 44.81, 'total_distance': 1979.7356261199764, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': 44.62, 'total_distance': 1981.256532656128, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': False, 'total_distance': 766.4582400815706, 'percentage_progress': 0.3899030233884769}
# {'checkpoint_time': False, 'total_distance': False, 'percentage_progress': False}
# {'checkpoint_time': False, 'total_distance': 2694.8969082349045, 'percentage_progress': 0.3899030233884769}
# {'checkpoint_time': False, 'total_distance': 799.5052693240259, 'percentage_progress': 0.4047347404449515}
# {'checkpoint_time': False, 'total_distance': False, 'percentage_progress': False}
# {'checkpoint_time': False, 'total_distance': 3095.5505780772955, 'percentage_progress': 0.5878494010268112}
# {'checkpoint_time': 40.78, 'total_distance': 2012.0582753119863, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': False, 'total_distance': 1176.5213579642402, 'percentage_progress': 0.587564175698802}
# {'checkpoint_time': 40.62, 'total_distance': 1988.3641711036964, 'percentage_progress': 0.9997147746719909}
# {'checkpoint_time': False, 'total_distance': 1155.438986699952, 'percentage_progress': 0.5878494010268112}
# {'checkpoint_time': False, 'total_distance': 1183.5570035420108, 'percentage_progress': 0.6015402167712492}
# {'checkpoint_time': False, 'total_distance': 778.8569820497131, 'percentage_progress': 0.40188248716486025}

# %% [markdown]
# # Display Pandas File

# %%
recording_df = pd.DataFrame({'checkpoint_time': checkpoint_time,
                             'total_distance': total_distance, 
                             'percentage_progress': percentage_progress})
recording_df = recording_df.fillna(0)
recording_df = recording_df[recording_df["percentage_progress"]> 0] 
recording_df
# Out:
#    checkpoint_time total_distance percentage_progress
# 2            False    1158.419403            0.587849
# 3            45.33    1996.241538            0.999715
# 4            False    1152.207175            0.587564
# 5            False    1840.133738            0.932402
# 8            False    4668.906056            0.403594
# 9            False     798.083662             0.40559
# 10           42.02    1993.593534            0.999715
# 11           40.95    1991.531595            0.999715
# 12           False     781.023876            0.390759
# 14           False    2696.187398            0.390473
# 16           45.56     3905.24379            0.999715
# 17           False    1179.094606             0.60097
# 18           43.03    1990.593622            0.999715
# 19           42.22    1996.442403            0.999715
# 20           False     841.887748            0.415003
# 21            42.9    1973.737342            0.999715
# 22           False     791.129446            0.397604
# 23           40.76    2006.581541            0.999715
# 26           False    4989.944647            0.590416
# 27           41.07    1995.325884            0.999715
# 29           45.32    3886.702246            0.999715
# 30           False    1193.216784            0.602681
# 31           41.55    1978.357936            0.999715
# 33           44.69    3897.694223            0.999715
# 34           49.75    1981.806975            0.999715
# 35           False    1192.299783            0.601255
# 40           40.96    8509.522579            0.999715
# 41           44.81    1979.735626            0.999715
# 42           44.62    1981.256533            0.999715
# 43           False      766.45824            0.389903
# 45           False    2694.896908            0.389903
# 46           False     799.505269            0.404735
# 48           False    3095.550578            0.587849
# 49           40.78    2012.058275            0.999715
# 50           False    1176.521358            0.587564
# 51           40.62    1988.364171            0.999715
# 52           False    1155.438987            0.587849
# 53           False    1183.557004             0.60154
# 54           False     778.856982            0.401882

# %% [markdown]
# # Record CSV File

# %%
file_name = f"{testing_track}_{model_watch_name}_{model_step}_.csv"
recording_df.to_csv(f"records/{file_name}")

# %%
file_name
# Out:
# 'C01_PPO_C01_TO_speed=1.2_1485k_.csv'
